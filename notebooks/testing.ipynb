# %%
import matplotlib.pyplot as plt
import numpy as np

from fold.analysis.sound_processor import Synthesizer

# %%
sound_file = r"/home/tortugellini/git/fold/sound_bites/Recording (13).m4a"
synthesizer = Synthesizer(sound_file)

# %%
synthesizer.load_sound()
# Out:
# /home/tortugellini/git/fold/src/fold/analysis/sound_processor.py:19: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.sound = librosa.load(self.sound_file, sr=None)
# /home/tortugellini/git/fold/.venv/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
sound = synthesizer.sound

# %%
sound, sample_rate = sound

# %%
plt.plot(sound)

# %%
plt.hist(np.abs(np.fft.fft(sound)), bins='scott')
plt.yscale("log")
